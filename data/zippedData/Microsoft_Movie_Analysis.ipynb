# %% [markdown]
# ## Microsoft Movie Analysis

# %%
import pandas as pd
import numpy as np
import sqlite3 as sql
import seaborn as sn
import matplotlib.pyplot as plt

# %% [markdown]
# df= pd.read_csv('tn.movie_budgets.csv.gz')
# df

# %% [markdown]
# ### Imported The Data I Wished to Analyze

# %% [markdown]
# df= pd.read_csv('tn.movie_budgets.csv.gz')
# df

# %% [markdown]
# ### Prepared the Budget Dataframe for Use
# #### Cleaned it
# #### Created net_pre_marketing to show the money made before marketing costs
# #### Created earnings/cost_ratio to show how much it made compared to budget
# #### Dropped all movies prior to 2010

# %%
budg= pd.read_csv('tn.movie_budgets.csv.gz')
budg['production_budget']=budg['production_budget'].str.replace(',','')
budg['domestic_gross']=budg['domestic_gross'].str.replace(',','')
budg['worldwide_gross']=budg['worldwide_gross'].str.replace(',','')
budg['production_budget']=budg['production_budget'].str.replace('$','').astype('int64')
budg['domestic_gross']=budg['domestic_gross'].str.replace('$','').astype('int64')
budg['worldwide_gross']=budg['worldwide_gross'].str.replace('$','').astype('int64')
#made sure the data was all integers in order for it to be able to sorted and analyzed
budg['net_pre_marketing']=budg['worldwide_gross']-budg['production_budget']
#made this column to indicate the best of my abilities the net profit
#it is unclear if advertising money is included(though i'm assuming it is not)
budg['domestic/world']=budg['domestic_gross']/budg['worldwide_gross']
#made this money to detirmine what percentage of worldwide earning were domestic
budg=budg.dropna()
budg['earnings/cost_ratio']=budg['net_pre_marketing']/budg['production_budget']
#this works as a percentage the movie recouperated its production budget
budg['year_released']=budg['release_date'].str[-4:].astype('int64')
#made a new column which has the year the film was released in order to be able to drop the movies made pre-2010
budg.drop(budg[budg['year_released'] < 2010].index, inplace = True)
budg.sort_values('earnings/cost_ratio').tail(25)
# Out:
#       id  release_date                    movie  production_budget  \
# 5216  17  Aug 23, 2013              You're Next            1000000
# 4590  91  Apr 13, 2018            Truth or Dare            3500000
# 5685  86   Jul 7, 2017            A Ghost Story             100000
# 4258  59  Oct 19, 2012    Paranormal Activity 4            5000000
# 2996  97  Nov 26, 2010      The Kingâs Speech           15000000
# 4668  69  Oct 12, 2012                 Sinister            3000000
# 4254  55  Jul 22, 2016               Lights Out            5000000
# 4666  67   Jun 7, 2013                The Purge            3000000
# 5358  59  Dec 30, 2011  Jodaeiye Nader az Simin             800000
# 3755  56  Dec 21, 2016                   Dangal            9500000
# 4252  53  Sep 13, 2013      Insidious Chapter 2            5000000
# 5014  15  Aug 27, 2010        The Last Exorcism            1800000
# 4083  84   Oct 3, 2014                Annabelle            6500000
# 4250  51  Oct 21, 2011    Paranormal Activity 3            5000000
# 5217  18  May 25, 2012        Chernobyl Diaries            1000000
# 5063  64  Oct 21, 2016                Moonlight            1500000
# 3517  18  May 25, 2012         Les Intouchables           10800000
# 4248  49  Feb 24, 2017                  Get Out            5000000
# 5189  90  Mar 21, 2014         Godâs Not Dead            1150000
# 4249  50  Jan 20, 2017                    Split            5000000
# 4664  65  Oct 20, 2010    Paranormal Activity 2            3000000
# 5213  14  Apr 17, 2015               Unfriended            1000000
# 5062  63   Apr 1, 2011                Insidious            1500000
# 5211  12   Jan 6, 2012         The Devil Inside            1000000
# 5679  80  Jul 10, 2015              The Gallows             100000
#
#       domestic_gross  worldwide_gross  net_pre_marketing  domestic/world  \
# 5216        18494006         26887177           25887177        0.687837
# 4590        41411015         95127344           91627344        0.435322
# 5685         1594798          2769782            2669782        0.575785
# 4258        53900335        142817992          137817992        0.377406
# 2996       138797449        430821168          415821168        0.322170
# 4668        48086903         87727807           84727807        0.548138
# 4254        67268835        148806510          143806510        0.452056
# 4666        64473115         91266581           88266581        0.706426
# 5358         7098492         24426169           23626169        0.290610
# 3755        12391761        294654618          285154618        0.042055
# 4252        83586447        161921515          156921515        0.516216
# 5014        41034350         70165900           68365900        0.584819
# 4083        84273813        256862920          250362920        0.328089
# 4250       104028807        207039844          202039844        0.502458
# 5217        18119640         42411721           41411721        0.427232
# 5063        27854931         65245512           63745512        0.426925
# 3517        13182281        484873045          474073045        0.027187
# 4248       176040665        255367951          250367951        0.689361
# 5189        60755732         63777092           62627092        0.952626
# 4249       138141585        278964806          273964806        0.495194
# 4664        84752907        177512032          174512032        0.477449
# 5213        32789645         64364198           63364198        0.509439
# 5062        54009150         99870886           98370886        0.540790
# 5211        53262945        101759490          100759490        0.523420
# 5679        22764410         41656474           41556474        0.546480
#
#       earnings/cost_ratio  year_released
# 5216            25.887177           2013
# 4590            26.179241           2018
# 5685            26.697820           2017
# 4258            27.563598           2012
# 2996            27.721411           2010
# 4668            28.242602           2012
# 4254            28.761302           2016
# 4666            29.422194           2013
# 5358            29.532711           2011
# 3755            30.016276           2016
# 4252            31.384303           2013
# 5014            37.981056           2010
# 4083            38.517372           2014
# 4250            40.407969           2011
# 5217            41.411721           2012
# 5063            42.497008           2016
# 3517            43.895652           2012
# 4248            50.073590           2017
# 5189            54.458341           2014
# 4249            54.792961           2017
# 4664            58.170677           2010
# 5213            63.364198           2015
# 5062            65.580591           2011
# 5211           100.759490           2012
# 5679           415.564740           2015

# %% [markdown]
# ### Created a Metric for Profitability
# #### Profitability actually occurs at an e/c ratio of 1, but not going to take this out for fear of consequences

# %%
#"in a very broad sense movies haven't made any money until
#their box office roughly equals twice the money spent on production."
#https://www.fool.com/investing/2019/08/06/why-box-office-results-dont-really-explain-how-mov.aspx#:~:text=But%20it's%20important%20to%20remember,the%20movie%20but%20marketing%20it.
#I am going to use the budget data to detirmine if a movie is profitable
#I can do this by creating a column that tells me if a movies earnings/cost ration is above 1 or not
budgP=budg
budgP['Profitable?']= np.where(budgP['earnings/cost_ratio']>= 2, True, False)
budgP.sort_values('earnings/cost_ratio')
# Out:
#       id  release_date                  movie  production_budget  \
# 5302   3  Dec 11, 2015          American Hero            1000000
# 4081  82  May 21, 2010     Perrierâs Bounty            6600000
# 3818  19   May 8, 2015             Skin Trade            9000000
# 5335  36  Nov 21, 2014            Food Chains             913000
# 3161  62   Sep 1, 2015          Broken Horses           15000000
# ...   ..           ...                    ...                ...
# 4664  65  Oct 20, 2010  Paranormal Activity 2            3000000
# 5213  14  Apr 17, 2015             Unfriended            1000000
# 5062  63   Apr 1, 2011              Insidious            1500000
# 5211  12   Jan 6, 2012       The Devil Inside            1000000
# 5679  80  Jul 10, 2015            The Gallows             100000
#
#       domestic_gross  worldwide_gross  net_pre_marketing  domestic/world  \
# 5302               0               26            -999974        0.000000
# 4081             828              828           -6599172        1.000000
# 3818            1242             1242           -8998758        1.000000
# 5335               0              176            -912824        0.000000
# 3161               0             3471          -14996529        0.000000
# ...              ...              ...                ...             ...
# 4664        84752907        177512032          174512032        0.477449
# 5213        32789645         64364198           63364198        0.509439
# 5062        54009150         99870886           98370886        0.540790
# 5211        53262945        101759490          100759490        0.523420
# 5679        22764410         41656474           41556474        0.546480
#
#       earnings/cost_ratio  year_released  Profitable?
# 5302            -0.999974           2015        False
# 4081            -0.999875           2010        False
# 3818            -0.999862           2015        False
# 5335            -0.999807           2014        False
# 3161            -0.999769           2015        False
# ...                   ...            ...          ...
# 4664            58.170677           2010         True
# 5213            63.364198           2015         True
# 5062            65.580591           2011         True
# 5211           100.759490           2012         True
# 5679           415.564740           2015         True
#
# [1922 rows x 11 columns]

# %% [markdown]
# ### Imported Cleaned dataset for project usage

# %%
mega_table= pd.read_csv('Merge_mega_table.csv')
mega_table.sort_values('worldwide_gross')
# Out:
#      Unnamed: 0     tconst  averagerating  numvotes                   movie  \
# 136         247  tt1763303            6.9   62589.0          The First Time
# 160         316  tt2059171            6.3   29550.0                 13 Sins
# 188         405  tt2398249            5.5   19832.0      They Came Together
# 249         586  tt4995790            7.2   44239.0              The Square
# 36           53  tt1183923            7.0   22210.0   Welcome to the Rileys
# ..          ...        ...            ...       ...                     ...
# 199         432  tt2582846            7.7  315135.0  The Fault in Our Stars
# 21           28  tt0970866            5.5   99222.0          Little Fockers
# 60          100  tt1343092            7.3  433165.0        The Great Gatsby
# 237         560  tt4465564            4.6   81706.0     Fifty Shades Darker
# 63          105  tt1396484            7.4  359123.0                      It
#
#      start_year  runtime_minutes                genres     id  release_date  \
# 136        2012             95.0  Comedy,Drama,Romance   67.0  Oct 19, 2012
# 160        2014             93.0       Horror,Thriller   51.0  Apr 18, 2014
# 188        2014             83.0        Comedy,Romance   58.0  Jun 27, 2014
# 249        2017            151.0          Comedy,Drama  100.0  Oct 25, 2013
# 36         2010            110.0                 Drama   12.0  Oct 29, 2010
# ..          ...              ...                   ...    ...           ...
# 199        2014            126.0         Drama,Romance   43.0   Jun 6, 2014
# 21         2010             98.0        Comedy,Romance   70.0  Dec 22, 2010
# 60         2013            143.0         Drama,Romance   70.0  May 10, 2013
# 237        2017            118.0         Drama,Romance   91.0  Feb 10, 2017
# 63         2017            135.0       Horror,Thriller   24.0   Sep 8, 2017
#
#      production_budget  domestic_gross  worldwide_gross  net_pre_marketing  \
# 136          2000000.0         17061.0          17061.0         -1982939.0
# 160          4000000.0          9134.0          47552.0         -3952448.0
# 188          3000000.0             0.0          82780.0         -2917220.0
# 249          1500000.0        124244.0         176262.0         -1323738.0
# 36          10000000.0        152857.0         355919.0         -9644081.0
# ..                 ...             ...              ...                ...
# 199         12000000.0     124872350.0      307166834.0        295166834.0
# 21         100000000.0     148438600.0      310650574.0        210650574.0
# 60         190000000.0     144840419.0      351040419.0        161040419.0
# 237         55000000.0     114434010.0      381398492.0        326398492.0
# 63          35000000.0     327481748.0      697457969.0        662457969.0
#
#      domestic/world  earnings/cost_ratio  year_released  Profitable?
# 136        1.000000            -0.991470         2012.0        False
# 160        0.192084            -0.988112         2014.0        False
# 188        0.000000            -0.972407         2014.0        False
# 249        0.704883            -0.882492         2013.0        False
# 36         0.429471            -0.964408         2010.0        False
# ..              ...                  ...            ...          ...
# 199        0.406529            24.597236         2014.0         True
# 21         0.477831             2.106506         2010.0         True
# 60         0.412603             0.847581         2013.0        False
# 237        0.300038             5.934518         2017.0         True
# 63         0.469536            18.927371         2017.0         True
#
# [269 rows x 18 columns]

# %%
best_margin=mega_table.sort_values('earnings/cost_ratio', ascending=False).head(20)
best_margin.value_counts('genres')
# Out:
# genres
# Horror,Thriller         6
# Drama,Romance           4
# Drama                   4
# Horror                  2
# Comedy,Drama            2
# Comedy,Drama,Romance    1
# Comedy                  1
# dtype: int64

# %%
sn.scatterplot(data=mega_table, x="production_budget", y="earnings/cost_ratio")
# Out:
# <AxesSubplot:xlabel='production_budget', ylabel='earnings/cost_ratio'>

# %%
mega_table2
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-7-10e662606bdd> in <module>
# ----> 1 mega_table2
#
# NameError: name 'mega_table2' is not defined

# %%
mega_table2= pd.read_csv('Merge_mega_table2.csv')
most_exp=mega_table2.sort_values('production_budget', ascending = False).head(30)
best_margin=mega_table2.sort_values('earnings/cost_ratio', ascending = False).head(30)

# %%
sn.scatterplot(data=best_margin, x="earnings/cost_ratio", y="production_budget")
# Out:
# <AxesSubplot:xlabel='earnings/cost_ratio', ylabel='production_budget'>

# %%
#due to microsoft being a mjor player financially, it would make sense for their film budget to be similar to other feature films
#being so, I'm going to filter the movies in the dataset to movies that cost over $70 mil to make, which was described as the low end of a feature film
#https://parlaystudios.com/blog/feature-film-budget-breakdown/
feature_films=mega_table2.loc[mega_table2['production_budget']>=50000000]
#feature_films.drop_duplicates(subset=['movie'])
feature_films
#some of the movie values appear suspecct, but should not have a greater impact on entire df
# Out:
#                                 movie     tconst  averagerating  numvotes  \
# 2     The Secret Life of Walter Mitty  tt0359950            7.3  275300.0
# 4                      Jurassic World  tt0369610            7.0  539338.0
# 7                             Tangled  tt0398286            7.8  366366.0
# 8                         John Carter  tt0401729            6.6  241792.0
# 9                 Dinner for Schmucks  tt0427152            5.9   91546.0
# ...                               ...        ...            ...       ...
# 1896                             Home  tt8601408            8.4      32.0
# 1901                              Red  tt8851190            8.1      26.0
# 1902                              Joy  tt8917752            6.5     430.0
# 1905                      Unstoppable  tt9225192            6.5     576.0
# 1909                      Unstoppable  tt9906218            8.1       8.0
#
#       start_year  runtime_minutes                      genres    id  \
# 2           2013            114.0      Adventure,Comedy,Drama  37.0
# 4           2015            124.0     Action,Adventure,Sci-Fi  34.0
# 7           2010            100.0  Adventure,Animation,Comedy  15.0
# 8           2012            132.0     Action,Adventure,Sci-Fi  14.0
# 9           2010            114.0                      Comedy  51.0
# ...          ...              ...                         ...   ...
# 1896        2018             71.0      Drama,Romance,Thriller  44.0
# 1901        2018             90.0                       Drama  63.0
# 1902        2018             99.0                       Drama  88.0
# 1905        2018            116.0                Action,Crime  19.0
# 1909        2019             84.0                 Documentary  19.0
#
#       release_date  production_budget  domestic_gross  worldwide_gross  \
# 2     Dec 25, 2013         91000000.0      58236838.0     1.878612e+08
# 4     Jun 12, 2015        215000000.0     652270625.0     1.648855e+09
# 7     Nov 24, 2010        260000000.0     200821936.0     5.864772e+08
# 8      Mar 9, 2012        275000000.0      73058679.0     2.827781e+08
# 9     Jul 30, 2010         69000000.0      73026337.0     8.679650e+07
# ...            ...                ...             ...              ...
# 1896  Mar 27, 2015        130000000.0     177397510.0     3.859979e+08
# 1901  Oct 15, 2010         60000000.0      90380162.0     1.964397e+08
# 1902  Dec 25, 2015         60000000.0      56451232.0     1.011341e+08
# 1905  Nov 12, 2010         95000000.0      81562942.0     1.657209e+08
# 1909  Nov 12, 2010         95000000.0      81562942.0     1.657209e+08
#
#       net_pre_marketing  domestic/world  earnings/cost_ratio  year_released  \
# 2          9.686118e+07        0.309999             1.064409         2013.0
# 4          1.433855e+09        0.395590             6.669092         2015.0
# 7          3.264772e+08        0.342421             1.255682         2010.0
# 8          7.778100e+06        0.258360             0.028284         2012.0
# 9          1.779650e+07        0.841351             0.257920         2010.0
# ...                 ...             ...                  ...            ...
# 1896       2.559979e+08        0.459582             1.969215         2015.0
# 1901       1.364397e+08        0.460091             2.273995         2010.0
# 1902       4.113406e+07        0.558182             0.685568         2015.0
# 1905       7.072092e+07        0.492170             0.744431         2010.0
# 1909       7.072092e+07        0.492170             0.744431         2010.0
#
#       Profitable? month_released
# 2            True            Dec
# 4            True            Jun
# 7            True            Nov
# 8           False            Mar
# 9           False            Jul
# ...           ...            ...
# 1896         True            Mar
# 1901         True            Oct
# 1902        False            Dec
# 1905        False            Nov
# 1909        False            Nov
#
# [499 rows x 18 columns]

# %%
most_prev=feature_films.value_counts('genres').head(20)
top20=most_prev.index
most_prev.index
# Out:
# Index(['Adventure,Animation,Comedy', 'Action,Adventure,Sci-Fi',
#        'Action,Adventure,Fantasy', 'Action,Adventure,Drama',
#        'Action,Adventure,Comedy', 'Action,Adventure,Animation', 'Drama',
#        'Comedy', 'Adventure,Family,Fantasy', 'Action,Adventure,Thriller',
#        'Documentary', 'Action,Comedy,Crime', 'Action,Crime,Thriller',
#        'Action,Thriller', 'Action,Drama,Thriller', 'Adventure,Comedy,Family',
#        'Action,Drama,Sci-Fi', 'Crime,Drama,Mystery', 'Action,Adventure,Family',
#        'Thriller'],
#       dtype='object', name='genres')

# %%
feature_top20=feature_films.loc[feature_films['genres'].isin(top20)]
genre_dict=dict(feature_top20.groupby('genres').net_pre_marketing.mean())
sort_genre_mean = sorted(genre_dict.items(), key=lambda x: x[1], reverse=True)
genre_mean_sorted=dict(sort_genre_mean)

# %%
feature_top20
# Out:
#                     movie     tconst  averagerating  numvotes  start_year  \
# 4          Jurassic World  tt0369610            7.0  539338.0        2015
# 7                 Tangled  tt0398286            7.8  366366.0        2010
# 8             John Carter  tt0401729            6.6  241792.0        2012
# 9     Dinner for Schmucks  tt0427152            5.9   91546.0        2010
# 10             The A-Team  tt0429493            6.8  235256.0        2010
# ...                   ...        ...            ...       ...         ...
# 1878       The Great Wall  tt7535780            6.5      24.0        2017
# 1882         Tomorrowland  tt7728220            6.3       7.0        2017
# 1901                  Red  tt8851190            8.1      26.0        2018
# 1902                  Joy  tt8917752            6.5     430.0        2018
# 1909          Unstoppable  tt9906218            8.1       8.0        2019
#
#       runtime_minutes                      genres    id  release_date  \
# 4               124.0     Action,Adventure,Sci-Fi  34.0  Jun 12, 2015
# 7               100.0  Adventure,Animation,Comedy  15.0  Nov 24, 2010
# 8               132.0     Action,Adventure,Sci-Fi  14.0   Mar 9, 2012
# 9               114.0                      Comedy  51.0  Jul 30, 2010
# 10              117.0   Action,Adventure,Thriller  32.0  Jun 11, 2010
# ...               ...                         ...   ...           ...
# 1878             72.0                 Documentary  92.0  Feb 17, 2017
# 1882             70.0                 Documentary  23.0  May 22, 2015
# 1901             90.0                       Drama  63.0  Oct 15, 2010
# 1902             99.0                       Drama  88.0  Dec 25, 2015
# 1909             84.0                 Documentary  19.0  Nov 12, 2010
#
#       production_budget  domestic_gross  worldwide_gross  net_pre_marketing  \
# 4           215000000.0     652270625.0     1.648855e+09       1.433855e+09
# 7           260000000.0     200821936.0     5.864772e+08       3.264772e+08
# 8           275000000.0      73058679.0     2.827781e+08       7.778100e+06
# 9            69000000.0      73026337.0     8.679650e+07       1.779650e+07
# 10          110000000.0      77222099.0     1.772412e+08       6.724117e+07
# ...                 ...             ...              ...                ...
# 1878        150000000.0      45157105.0     3.344869e+08       1.844869e+08
# 1882        170000000.0      93436322.0     2.066275e+08       3.662752e+07
# 1901         60000000.0      90380162.0     1.964397e+08       1.364397e+08
# 1902         60000000.0      56451232.0     1.011341e+08       4.113406e+07
# 1909         95000000.0      81562942.0     1.657209e+08       7.072092e+07
#
#       domestic/world  earnings/cost_ratio  year_released  Profitable?  \
# 4           0.395590             6.669092         2015.0         True
# 7           0.342421             1.255682         2010.0         True
# 8           0.258360             0.028284         2012.0        False
# 9           0.841351             0.257920         2010.0        False
# 10          0.435689             0.611283         2010.0        False
# ...              ...                  ...            ...          ...
# 1878        0.135004             1.229912         2017.0         True
# 1882        0.452197             0.215456         2015.0        False
# 1901        0.460091             2.273995         2010.0         True
# 1902        0.558182             0.685568         2015.0        False
# 1909        0.492170             0.744431         2010.0        False
#
#      month_released
# 4               Jun
# 7               Nov
# 8               Mar
# 9               Jul
# 10              Jun
# ...             ...
# 1878            Feb
# 1882            May
# 1901            Oct
# 1902            Dec
# 1909            Nov
#
# [319 rows x 18 columns]

# %%
x = genre_mean_sorted.keys()
y = genre_mean_sorted.values()
plot_one_fig, plot_one_ax= plt.subplots(figsize=(20, 10))
plot_one_ax.set_title('Average Money Grossed by Genre', fontsize=25)
plot_one_ax.set_ylabel('Worldwide Gross', fontsize=20)
plot_one_ax.set_xlabel('Genre Name', fontsize=20)
plot_one_ax.bar(x,y)
plt.xticks(rotation=90)
plt.yticks(np.arange(0, 1000000000, 100000000));

# %%
actadvensci=feature_top20.loc[feature_top20['genres']== 'Action,Adventure,Sci-Fi']
actadvensci.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 50 entries, 4 to 1838
# Data columns (total 18 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   movie                50 non-null     object
#  1   tconst               50 non-null     object
#  2   averagerating        50 non-null     float64
#  3   numvotes             50 non-null     float64
#  4   start_year           50 non-null     int64
#  5   runtime_minutes      50 non-null     float64
#  6   genres               50 non-null     object
#  7   id                   50 non-null     float64
#  8   release_date         50 non-null     object
#  9   production_budget    50 non-null     float64
#  10  domestic_gross       50 non-null     float64
#  11  worldwide_gross      50 non-null     float64
#  12  net_pre_marketing    50 non-null     float64
#  13  domestic/world       50 non-null     float64
#  14  earnings/cost_ratio  50 non-null     float64
#  15  year_released        50 non-null     float64
#  16  Profitable?          50 non-null     bool
#  17  month_released       50 non-null     object
# dtypes: bool(1), float64(11), int64(1), object(5)
# memory usage: 7.1+ KB

# %%
actadvencom=feature_top20.loc[feature_top20['genres']== 'Action,Adventure,Comedy']
actadvencom.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 18 entries, 19 to 1742
# Data columns (total 18 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   movie                18 non-null     object
#  1   tconst               18 non-null     object
#  2   averagerating        18 non-null     float64
#  3   numvotes             18 non-null     float64
#  4   start_year           18 non-null     int64
#  5   runtime_minutes      18 non-null     float64
#  6   genres               18 non-null     object
#  7   id                   18 non-null     float64
#  8   release_date         18 non-null     object
#  9   production_budget    18 non-null     float64
#  10  domestic_gross       18 non-null     float64
#  11  worldwide_gross      18 non-null     float64
#  12  net_pre_marketing    18 non-null     float64
#  13  domestic/world       18 non-null     float64
#  14  earnings/cost_ratio  18 non-null     float64
#  15  year_released        18 non-null     float64
#  16  Profitable?          18 non-null     bool
#  17  month_released       18 non-null     object
# dtypes: bool(1), float64(11), int64(1), object(5)
# memory usage: 2.5+ KB

# %%
actadvenani=feature_top20.loc[feature_top20['genres']== 'Action,Adventure,Animation']
actadvenani.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 15 entries, 20 to 1600
# Data columns (total 18 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   movie                15 non-null     object
#  1   tconst               15 non-null     object
#  2   averagerating        15 non-null     float64
#  3   numvotes             15 non-null     float64
#  4   start_year           15 non-null     int64
#  5   runtime_minutes      15 non-null     float64
#  6   genres               15 non-null     object
#  7   id                   15 non-null     float64
#  8   release_date         15 non-null     object
#  9   production_budget    15 non-null     float64
#  10  domestic_gross       15 non-null     float64
#  11  worldwide_gross      15 non-null     float64
#  12  net_pre_marketing    15 non-null     float64
#  13  domestic/world       15 non-null     float64
#  14  earnings/cost_ratio  15 non-null     float64
#  15  year_released        15 non-null     float64
#  16  Profitable?          15 non-null     bool
#  17  month_released       15 non-null     object
# dtypes: bool(1), float64(11), int64(1), object(5)
# memory usage: 2.1+ KB

# %%
feature_top20['month_released']=feature_top20['release_date'].str[:3]
# Out:
# <ipython-input-18-b04bc0a7de21>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   feature_top20['month_released']=feature_top20['release_date'].str[:3]

# %%
ax = sn.stripplot(x="worldwide_gross", y="month_released", data=feature_top20)

# %%
mega_table2['month_released']=mega_table2['release_date'].str[:3]
period1=['Jan','Feb','Mar','Apr']
period_1=mega_table2.loc[mega_table2['month_released'].isin(period1)]
period2=['May','Jun','Jul','Aug']
period_2=mega_table2.loc[mega_table2['month_released'].isin(period2)]
period3=['Sep','Oct','Nov','Dec']
period_3=mega_table2.loc[mega_table2['month_released'].isin(period3)]

# %%
period_1[period_1['numvotes']>= 10000]
# Out:
#                          movie     tconst  averagerating  numvotes  \
# 1                  On the Road  tt0337692            6.1   37886.0
# 6            The Three Stooges  tt0383010            5.1   28570.0
# 8                  John Carter  tt0401729            6.6  241792.0
# 15         Alita: Battle Angel  tt0437086            7.5   88207.0
# 19                     Shazam!  tt0448115            7.4  109051.0
# ...                        ...        ...            ...       ...
# 1852                        Us  tt6857112            7.1  102511.0
# 1867                    Unsane  tt7153766            6.4   32049.0
# 1880             What Men Want  tt7634968            4.9   10141.0
# 1889  Dragon Ball Super: Broly  tt7961060            8.0   16465.0
# 1892        Happy Death Day 2U  tt8155288            6.3   27462.0
#
#       start_year  runtime_minutes                      genres    id  \
# 1           2012            124.0     Adventure,Drama,Romance  17.0
# 6           2012             92.0               Comedy,Family   4.0
# 8           2012            132.0     Action,Adventure,Sci-Fi  14.0
# 15          2019            122.0     Action,Adventure,Sci-Fi  24.0
# 19          2019            132.0     Action,Adventure,Comedy  97.0
# ...          ...              ...                         ...   ...
# 1852        2019            116.0     Horror,Mystery,Thriller  88.0
# 1867        2018             98.0        Drama,Horror,Mystery  70.0
# 1880        2019            117.0      Comedy,Fantasy,Romance  21.0
# 1889        2018            100.0  Action,Adventure,Animation  36.0
# 1892        2019            100.0        Drama,Horror,Mystery  78.0
#
#       release_date  production_budget  domestic_gross  worldwide_gross  \
# 1     Mar 22, 2013         25000000.0        720828.0        9313302.0
# 6     Apr 13, 2012         30000000.0      44338224.0       54052249.0
# 8      Mar 9, 2012        275000000.0      73058679.0      282778100.0
# 15    Feb 14, 2019        170000000.0      85710210.0      402976036.0
# 19     Apr 5, 2019         85000000.0     139606856.0      362899733.0
# ...            ...                ...             ...              ...
# 1852  Mar 22, 2019         20000000.0     175006930.0      254210310.0
# 1867  Mar 23, 2018          1500000.0       7690044.0       14244931.0
# 1880   Feb 8, 2019         20000000.0      54611903.0       69911903.0
# 1889  Jan 16, 2019          8500000.0      30376755.0      122747755.0
# 1892  Feb 13, 2019          9000000.0      28051045.0       64179495.0
#
#       net_pre_marketing  domestic/world  earnings/cost_ratio  year_released  \
# 1           -15686698.0        0.077398            -0.627468         2013.0
# 6            24052249.0        0.820285             0.801742         2012.0
# 8             7778100.0        0.258360             0.028284         2012.0
# 15          232976036.0        0.212693             1.370447         2019.0
# 19          277899733.0        0.384698             3.269409         2019.0
# ...                 ...             ...                  ...            ...
# 1852        234210310.0        0.688434            11.710515         2019.0
# 1867         12744931.0        0.539844             8.496621         2018.0
# 1880         49911903.0        0.781153             2.495595         2019.0
# 1889        114247755.0        0.247473            13.440912         2019.0
# 1892         55179495.0        0.437072             6.131055         2019.0
#
#       Profitable? month_released
# 1           False            Mar
# 6           False            Apr
# 8           False            Mar
# 15           True            Feb
# 19           True            Apr
# ...           ...            ...
# 1852         True            Mar
# 1867         True            Mar
# 1880         True            Feb
# 1889         True            Jan
# 1892         True            Feb
#
# [409 rows x 18 columns]

# %%
period_2[period_2['numvotes']>= 10000]
p2genres=period_2.value_counts('genres').head(20)
p2mostprev=p2genres.index
period_2_top_genres=period_2.loc[period_2['genres'].isin(p2mostprev)]

# %%
period_3[period_3['numvotes']>= 10000]
# Out:
#                                 movie     tconst  averagerating  numvotes  \
# 2     The Secret Life of Walter Mitty  tt0359950            7.3  275300.0
# 3         A Walk Among the Tombstones  tt0365907            6.5  105116.0
# 5                       The Rum Diary  tt0376136            6.2   94787.0
# 7                             Tangled  tt0398286            7.8  366366.0
# 12                         Real Steel  tt0433035            7.1  283534.0
# ...                               ...        ...            ...       ...
# 1863       If Beale Street Could Talk  tt7125860            7.2   25512.0
# 1865                        Destroyer  tt7137380            6.2   13683.0
# 1875                   Instant Family  tt7401588            7.4   46728.0
# 1888                         The Mule  tt7959026            7.1   58955.0
# 1897                  Fahrenheit 11/9  tt8632862            6.7   11628.0
#
#       start_year  runtime_minutes                      genres     id  \
# 2           2013            114.0      Adventure,Comedy,Drama   37.0
# 3           2014            114.0          Action,Crime,Drama   67.0
# 5           2011            119.0                Comedy,Drama   16.0
# 7           2010            100.0  Adventure,Animation,Comedy   15.0
# 12          2011            127.0         Action,Drama,Family   31.0
# ...          ...              ...                         ...    ...
# 1863        2018            119.0               Drama,Romance   96.0
# 1865        2018            121.0          Action,Crime,Drama    5.0
# 1875        2018            118.0                Comedy,Drama   20.0
# 1888        2018            116.0        Crime,Drama,Thriller  100.0
# 1897        2018            128.0                 Documentary   29.0
#
#       release_date  production_budget  domestic_gross  worldwide_gross  \
# 2     Dec 25, 2013         91000000.0      58236838.0      187861183.0
# 3     Sep 19, 2014         28000000.0      26017685.0       62108587.0
# 5     Oct 28, 2011         45000000.0      13109815.0       21544732.0
# 7     Nov 24, 2010        260000000.0     200821936.0      586477240.0
# 12     Oct 7, 2011        110000000.0      85463309.0      263880341.0
# ...            ...                ...             ...              ...
# 1863  Dec 14, 2018         12000000.0      14915773.0       19859167.0
# 1865  Dec 25, 2018          9000000.0       1533324.0        3681096.0
# 1875  Nov 16, 2018         48000000.0      67363237.0      119736188.0
# 1888  Dec 14, 2018         50000000.0     103804407.0      170857676.0
# 1897  Sep 21, 2018          5000000.0       6352306.0        6653715.0
#
#       net_pre_marketing  domestic/world  earnings/cost_ratio  year_released  \
# 2            96861183.0        0.309999             1.064409         2013.0
# 3            34108587.0        0.418906             1.218164         2014.0
# 5           -23455268.0        0.608493            -0.521228         2011.0
# 7           326477240.0        0.342421             1.255682         2010.0
# 12          153880341.0        0.323871             1.398912         2011.0
# ...                 ...             ...                  ...            ...
# 1863          7859167.0        0.751077             0.654931         2018.0
# 1865         -5318904.0        0.416540            -0.590989         2018.0
# 1875         71736188.0        0.562597             1.494504         2018.0
# 1888        120857676.0        0.607549             2.417154         2018.0
# 1897          1653715.0        0.954701             0.330743         2018.0
#
#       Profitable? month_released
# 2            True            Dec
# 3            True            Sep
# 5           False            Oct
# 7            True            Nov
# 12           True            Oct
# ...           ...            ...
# 1863        False            Dec
# 1865        False            Dec
# 1875         True            Nov
# 1888         True            Dec
# 1897        False            Sep
#
# [483 rows x 18 columns]

# %%
sn.scatterplot(data=period_3, x="averagerating", y="worldwide_gross")
# Out:
# <AxesSubplot:xlabel='averagerating', ylabel='worldwide_gross'>

# %%
period_2_top_genres['ec_ratio']=period_2_top_genres["earnings/cost_ratio"]
# Out:
# <ipython-input-25-80650c671d28>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   period_2_top_genres['ec_ratio']=period_2_top_genres["earnings/cost_ratio"]

# %%
period_2_top_genres.sort_values('ec_ratio')
period_2_top_genres = period_2_top_genres.drop(1119)

# %%
period_2_top_genres.describe()
# Out:
#        averagerating      numvotes   start_year  runtime_minutes          id  \
# count     320.000000  3.200000e+02   320.000000       320.000000  320.000000
# mean        6.371563  1.321516e+05  2013.837500       104.806250   50.868750
# std         0.993855  2.003022e+05     2.629439        19.595277   28.534008
# min         2.400000  5.000000e+00  2010.000000        40.000000    2.000000
# 25%         5.800000  5.543000e+03  2011.000000        91.750000   27.000000
# 50%         6.400000  6.012050e+04  2014.000000       103.000000   51.000000
# 75%         7.100000  1.748255e+05  2016.000000       117.000000   76.000000
# max         9.200000  1.841066e+06  2019.000000       165.000000  100.000000
#
#        production_budget  domestic_gross  worldwide_gross  net_pre_marketing  \
# count       3.200000e+02    3.200000e+02     3.200000e+02       3.200000e+02
# mean        6.134569e+07    7.891484e+07     2.063965e+08       1.450509e+08
# std         7.410501e+07    1.074239e+08     3.020167e+08       2.490184e+08
# min         5.000000e+04    0.000000e+00     1.242000e+03      -2.002376e+08
# 25%         7.375000e+06    1.798489e+06     7.419838e+06      -4.017250e+04
# 50%         2.750000e+07    4.108214e+07     7.065228e+07       4.114846e+07
# 75%         1.000000e+08    1.054871e+08     2.742566e+08       1.714554e+08
# max         4.106000e+08    6.522706e+08     1.648855e+09       1.433855e+09
#
#        domestic/world  earnings/cost_ratio  year_released    ec_ratio
# count      320.000000           320.000000     320.000000  320.000000
# mean         0.503036             2.693813    2013.950000    2.693813
# std          0.293134             5.102112       2.518396    5.102112
# min          0.000000            -0.999862    2010.000000   -0.999862
# 25%          0.304300            -0.012097    2012.000000   -0.012097
# 50%          0.451152             1.258581    2014.000000    1.258581
# 75%          0.742428             3.248681    2016.000000    3.248681
# max          1.000000            41.411721    2019.000000   41.411721

# %%
genre_dict2=dict(period_2_top_genres.groupby('genres').ec_ratio.mean())
sort_genre_mean2 = sorted(genre_dict2.items(), key=lambda x: x[1], reverse=True)
genre_mean_sorted2=dict(sort_genre_mean2)
genre_mean_sorted2
plot_two, plot_two_ax= plt.subplots(figsize=(20, 10))
plot_two_ax.bar(genre_mean_sorted2.keys(),genre_mean_sorted2.values())
plot_two_ax.set_title('Period 2 Average Earnings/Cost Ratio by Genre', fontsize=25)
plot_two_ax.set_ylabel('E/C Ratio', fontsize=20)
plot_two_ax.set_xlabel('Genre Name', fontsize=20)
plt.xticks(rotation=90);

# %%
genre_dict2_=dict(period_2_top_genres.groupby('genres').net_pre_marketing.mean())
sort_genre_mean2_ = sorted(genre_dict2_.items(), key=lambda x: x[1], reverse=True)
genre_mean_sorted2_=dict(sort_genre_mean2_)
genre_mean_sorted2_
plot_two_, plot_two_ax_= plt.subplots(figsize=(20, 10))
plot_two_ax_.bar(genre_mean_sorted2_.keys(),genre_mean_sorted2_.values())
plot_two_ax_.set_title('Period 2 Average Net Profit Before Marketing Costs', fontsize=25)
plot_two_ax_.set_ylabel('Net Profit', fontsize=20)
plot_two_ax_.set_xlabel('Genre Name', fontsize=20)
plt.xticks(rotation=90);

# %%
genre_dict2__=dict(period_2_top_genres.groupby('genres').worldwide_gross.mean())
sort_genre_mean2__ = sorted(genre_dict2__.items(), key=lambda x: x[1], reverse=True)
genre_mean_sorted2__=dict(sort_genre_mean2__)
genre_mean_sorted2__
plot_two_, plot_two_ax_= plt.subplots(figsize=(20, 10))
plot_two_ax_.bar(genre_mean_sorted2__.keys(),genre_mean_sorted2__.values())
plot_two_ax_.set_title('Period 2 Average Worldwide Gross by Genre', fontsize=25)
plot_two_ax_.set_ylabel('Worldwide gross', fontsize=20)
plot_two_ax_.set_xlabel('Genre Name', fontsize=20)
plt.xticks(rotation=90);

# %%
top20_genres=mega_table2.value_counts('genres').head(20)
top20_genres
# Out:
# genres
# Drama                         131
# Adventure,Animation,Comedy     69
# Comedy,Drama                   65
# Comedy                         63
# Comedy,Drama,Romance           62
# Documentary                    59
# Action,Adventure,Sci-Fi        53
# Drama,Romance                  52
# Comedy,Romance                 47
# Action,Crime,Drama             43
# Action,Adventure,Fantasy       35
# Horror,Mystery,Thriller        35
# Action,Comedy,Crime            32
# Horror,Thriller                31
# Crime,Drama,Thriller           30
# Drama,Thriller                 30
# Action,Adventure,Drama         29
# Horror                         28
# Biography,Drama,History        26
# Action,Crime,Thriller          24
# dtype: int64

# %%
mega=mega_table2.loc[mega_table2['production_budget']>=50000000]

# %%
mega_table2_votes=mega_table2[mega_table2['numvotes']>= 10000]

# %%
mega_table2_votes5=mega_table2[mega_table2['numvotes']>= 1000]

# %%
mega_table2_votes50=mega_table2_votes.sort_values('worldwide_gross', ascending=False).head(50)

# %%
sn.scatterplot(data=mega_table2_votes50, x="averagerating", y="worldwide_gross").set(title='Rating vs World Wide Gross')
# Out:
# [Text(0.5, 1.0, 'Rating vs World Wide Gross')]

# %%
mega_table2_horrormt=mega_table2_votes5.loc[mega_table2_votes5['genres']=='Horror,Mystery,Thriller']
mega_table2_horrormt.sort_values('averagerating')
# Out:
#                                          movie     tconst  averagerating  \
# 1763                               Slender Man  tt5690360            3.2
# 1298                               Devil's Due  tt2752758            4.1
# 1119                               The Gallows  tt2309260            4.2
# 224                                      Ouija  tt1204977            4.5
# 903                                     Exeter  tt1945044            4.5
# 1214  Paranormal Activity: The Ghost Dimension  tt2473510            4.6
# 1007                     Paranormal Activity 4  tt2109184            4.6
# 1433                                The Forest  tt3387542            4.8
# 90                             My Soul to Take  tt0872230            4.8
# 540                                Blair Witch  tt1540011            5.0
# 941                          Chernobyl Diaries  tt1991245            5.0
# 1216      Paranormal Activity: The Marked Ones  tt2473682            5.0
# 1768            The Possession of Hannah Grace  tt5734576            5.2
# 1646                                     Braid  tt4638148            5.3
# 1299                                Sinister 2  tt2752772            5.3
# 1424                                 Annabelle  tt3322940            5.4
# 1505                                Unfriended  tt3713166            5.6
# 1767                   Insidious: The Last Key  tt5726086            5.7
# 790                      Paranormal Activity 3  tt1778304            5.8
# 11                              The Possession  tt0431021            5.9
# 1544                                   The Boy  tt3882082            6.0
# 82                                Pet Sematary  tt0837563            6.0
# 1478                                 The Visit  tt3567288            6.2
# 331                                      Devil  tt1314655            6.2
# 1161                      Deliver Us from Evil  tt2377322            6.2
# 1719                       Annabelle: Creation  tt5140878            6.5
# 1732                           Happy Death Day  tt5308322            6.5
# 893                                   Sinister  tt1922777            6.8
# 585                                  Insidious  tt1591095            6.9
# 1852                                        Us  tt6857112            7.1
# 466                              The Conjuring  tt1457767            7.5
# 1710                                   Get Out  tt5052448            7.7
#
#       numvotes  start_year  runtime_minutes                   genres    id  \
# 1763   19650.0        2018             93.0  Horror,Mystery,Thriller  80.0
# 1298   15502.0        2014             89.0  Horror,Mystery,Thriller  14.0
# 1119   17763.0        2015             81.0  Horror,Mystery,Thriller  80.0
# 224    44054.0        2014             89.0  Horror,Mystery,Thriller  60.0
# 903     5156.0        2015             91.0  Horror,Mystery,Thriller  49.0
# 1214   22361.0        2015             88.0  Horror,Mystery,Thriller   7.0
# 1007   58408.0        2012             88.0  Horror,Mystery,Thriller  59.0
# 1433   36423.0        2016             93.0  Horror,Mystery,Thriller  92.0
# 90     18381.0        2010            107.0  Horror,Mystery,Thriller  68.0
# 540    36867.0        2016             89.0  Horror,Mystery,Thriller   1.0
# 941    60304.0        2012             86.0  Horror,Mystery,Thriller  18.0
# 1216   37147.0        2014             84.0  Horror,Mystery,Thriller  70.0
# 1768   11629.0        2018             86.0  Horror,Mystery,Thriller  37.0
# 1646    1115.0        2018             82.0  Horror,Mystery,Thriller  48.0
# 1299   41782.0        2015             97.0  Horror,Mystery,Thriller  91.0
# 1424  122039.0        2014             99.0  Horror,Mystery,Thriller  84.0
# 1505   62043.0        2014             83.0  Horror,Mystery,Thriller  14.0
# 1767   42154.0        2018            103.0  Horror,Mystery,Thriller  45.0
# 790    85689.0        2011             83.0  Horror,Mystery,Thriller  51.0
# 11     53649.0        2012             92.0  Horror,Mystery,Thriller  81.0
# 1544   68957.0        2016             97.0  Horror,Mystery,Thriller  68.0
# 82     34472.0        2019            101.0  Horror,Mystery,Thriller  61.0
# 1478  102459.0        2015             94.0  Horror,Mystery,Thriller  56.0
# 331   122080.0        2010             80.0  Horror,Mystery,Thriller  71.0
# 1161   63793.0        2014            118.0  Horror,Mystery,Thriller  34.0
# 1719   90402.0        2017            109.0  Horror,Mystery,Thriller   2.0
# 1732   87132.0        2017             96.0  Horror,Mystery,Thriller  58.0
# 893   198345.0        2012            110.0  Horror,Mystery,Thriller  69.0
# 585   254197.0        2010            103.0  Horror,Mystery,Thriller  63.0
# 1852  102511.0        2019            116.0  Horror,Mystery,Thriller  88.0
# 466   397233.0        2013            112.0  Horror,Mystery,Thriller  93.0
# 1710  400474.0        2017            104.0  Horror,Mystery,Thriller  49.0
#
#       release_date  production_budget  domestic_gross  worldwide_gross  \
# 1763  Aug 10, 2018         10000000.0      30564825.0       51723644.0
# 1298  Jan 17, 2014          7000000.0      15821461.0       36146087.0
# 1119  Jul 10, 2015           100000.0      22764410.0       41656474.0
# 224   Oct 24, 2014          5000000.0      50856010.0      103300632.0
# 903    Sep 1, 2015            25000.0             0.0         489792.0
# 1214  Oct 23, 2015         10000000.0      18297124.0       77959374.0
# 1007  Oct 19, 2012          5000000.0      53900335.0      142817992.0
# 1433   Jan 8, 2016         10000000.0      26594261.0       40749230.0
# 90     Oct 8, 2010         25000000.0      14744435.0       16727470.0
# 540   Sep 16, 2016         10000000.0      20777061.0       38985577.0
# 941   May 25, 2012          1000000.0      18119640.0       42411721.0
# 1216   Jan 3, 2014          5000000.0      32462372.0       90904854.0
# 1768  Nov 30, 2018          6000000.0      14836174.0       42785387.0
# 1646   Feb 1, 2019          1660000.0             0.0          80745.0
# 1299  Aug 21, 2015         10000000.0      27740955.0       54104225.0
# 1424   Oct 3, 2014          6500000.0      84273813.0      256862920.0
# 1505  Apr 17, 2015          1000000.0      32789645.0       64364198.0
# 1767   Jan 5, 2018         10000000.0      67745330.0      167885588.0
# 790   Oct 21, 2011          5000000.0     104028807.0      207039844.0
# 11    Aug 31, 2012         14000000.0      49130588.0       82925064.0
# 1544  Jan 22, 2016         10000000.0      35819556.0       68220952.0
# 82     Apr 5, 2019         21000000.0      54724696.0      109501146.0
# 1478  Sep 11, 2015          5000000.0      65206105.0       98677816.0
# 331   Sep 17, 2010         10000000.0      33679655.0       63354114.0
# 1161   Jul 2, 2014         30000000.0      30577122.0       87956618.0
# 1719  Aug 11, 2017         15000000.0     102092201.0      305384865.0
# 1732  Oct 13, 2017          5000000.0      55683845.0      125010260.0
# 893   Oct 12, 2012          3000000.0      48086903.0       87727807.0
# 585    Apr 1, 2011          1500000.0      54009150.0       99870886.0
# 1852  Mar 22, 2019         20000000.0     175006930.0      254210310.0
# 466   Jul 19, 2013         20000000.0     137400141.0      318000141.0
# 1710  Feb 24, 2017          5000000.0     176040665.0      255367951.0
#
#       net_pre_marketing  domestic/world  earnings/cost_ratio  year_released  \
# 1763         41723644.0        0.590926             4.172364         2018.0
# 1298         29146087.0        0.437709             4.163727         2014.0
# 1119         41556474.0        0.546480           415.564740         2015.0
# 224          98300632.0        0.492311            19.660126         2014.0
# 903            464792.0        0.000000            18.591680         2015.0
# 1214         67959374.0        0.234701             6.795937         2015.0
# 1007        137817992.0        0.377406            27.563598         2012.0
# 1433         30749230.0        0.652632             3.074923         2016.0
# 90           -8272530.0        0.881450            -0.330901         2010.0
# 540          28985577.0        0.532942             2.898558         2016.0
# 941          41411721.0        0.427232            41.411721         2012.0
# 1216         85904854.0        0.357103            17.180971         2014.0
# 1768         36785387.0        0.346758             6.130898         2018.0
# 1646         -1579255.0        0.000000            -0.951358         2019.0
# 1299         44104225.0        0.512732             4.410423         2015.0
# 1424        250362920.0        0.328089            38.517372         2014.0
# 1505         63364198.0        0.509439            63.364198         2015.0
# 1767        157885588.0        0.403521            15.788559         2018.0
# 790         202039844.0        0.502458            40.407969         2011.0
# 11           68925064.0        0.592470             4.923219         2012.0
# 1544         58220952.0        0.525052             5.822095         2016.0
# 82           88501146.0        0.499764             4.214340         2019.0
# 1478         93677816.0        0.660798            18.735563         2015.0
# 331          53354114.0        0.531610             5.335411         2010.0
# 1161         57956618.0        0.347639             1.931887         2014.0
# 1719        290384865.0        0.334307            19.358991         2017.0
# 1732        120010260.0        0.445434            24.002052         2017.0
# 893          84727807.0        0.548138            28.242602         2012.0
# 585          98370886.0        0.540790            65.580591         2011.0
# 1852        234210310.0        0.688434            11.710515         2019.0
# 466         298000141.0        0.432076            14.900007         2013.0
# 1710        250367951.0        0.689361            50.073590         2017.0
#
#       Profitable? month_released
# 1763         True            Aug
# 1298         True            Jan
# 1119         True            Jul
# 224          True            Oct
# 903          True            Sep
# 1214         True            Oct
# 1007         True            Oct
# 1433         True            Jan
# 90          False            Oct
# 540          True            Sep
# 941          True            May
# 1216         True            Jan
# 1768         True            Nov
# 1646        False            Feb
# 1299         True            Aug
# 1424         True            Oct
# 1505         True            Apr
# 1767         True            Jan
# 790          True            Oct
# 11           True            Aug
# 1544         True            Jan
# 82           True            Apr
# 1478         True            Sep
# 331          True            Sep
# 1161         True            Jul
# 1719         True            Aug
# 1732         True            Oct
# 893          True            Oct
# 585          True            Apr
# 1852         True            Mar
# 466          True            Jul
# 1710         True            Feb

# %%
mega_table2_horrormt=mega_table2_horrormt.drop(1119)
sn.scatterplot(data=mega_table2_horrormt, x="production_budget", y="earnings/cost_ratio")
# Out:
# <AxesSubplot:xlabel='production_budget', ylabel='earnings/cost_ratio'>

# %%
mega_table2_horrormt.describe()
# Out:
#        averagerating       numvotes   start_year  runtime_minutes         id  \
# count      31.000000      31.000000    31.000000        31.000000  31.000000
# mean        5.609677   86980.903226  2014.677419        95.548387  54.225806
# std         1.028382   99406.559131     2.688086        10.471672  27.233202
# min         3.200000    1115.000000  2010.000000        80.000000   1.000000
# 25%         4.900000   35447.500000  2012.500000        88.000000  41.000000
# 50%         5.600000   58408.000000  2015.000000        93.000000  59.000000
# 75%         6.200000   96430.500000  2017.000000       103.000000  70.500000
# max         7.700000  400474.000000  2019.000000       118.000000  93.000000
#
#        production_budget  domestic_gross  worldwide_gross  net_pre_marketing  \
# count       3.100000e+01    3.100000e+01     3.100000e+01       3.100000e+01
# mean        9.280161e+06    5.261322e+07     1.094047e+08       1.001246e+08
# std         7.383525e+06    4.501006e+07     8.794989e+07       8.653807e+07
# min         2.500000e+04    0.000000e+00     8.074500e+04      -8.272530e+06
# 25%         5.000000e+06    2.368566e+07     4.725452e+07       4.156768e+07
# 50%         7.000000e+06    3.581956e+07     8.772781e+07       6.892506e+07
# 75%         1.000000e+07    6.044498e+07     1.339141e+08       1.289141e+08
# max         3.000000e+07    1.760407e+08     3.180001e+08       2.980001e+08
#
#        domestic/world  earnings/cost_ratio  year_released
# count       31.000000            31.000000      31.000000
# mean         0.465267            18.312311    2014.774194
# std          0.181481            18.274722       2.679673
# min          0.000000            -0.951358    2010.000000
# 25%          0.367254             4.312381    2012.500000
# 50%          0.499764            14.900007    2015.000000
# 75%          0.544464            25.782825    2017.000000
# max          0.881450            65.580591    2019.000000

# %%
actiontableau=pd.read_csv('action_table.csv')
actiontableau
# Out:
#      Unnamed: 0     tconst  averagerating  numvotes                 movie  \
# 0            39  tt0369610           7.00 539338.00        Jurassic World
# 1            50  tt0401729           6.60 241792.00           John Carter
# 2            68  tt0429493           6.80 235256.00            The A-Team
# 3            72  tt0433035           7.10 283534.00            Real Steel
# 4            78  tt0437086           7.50  88207.00   Alita: Battle Angel
# ..          ...        ...            ...       ...                   ...
# 193       45547  tt5013056           7.90 466580.00               Dunkirk
# 194       46167  tt5095030           7.10 244024.00  Ant-Man and the Wasp
# 195       48760  tt5463162           7.80 391735.00            Deadpool 2
# 196       50822  tt5758778           5.80  81193.00            Skyscraper
# 197       56025  tt6565702           6.00  24451.00          Dark Phoenix
#
#      start_year  runtime_minutes                     genres    id  \
# 0          2015           124.00    Action,Adventure,Sci-Fi 34.00
# 1          2012           132.00    Action,Adventure,Sci-Fi 14.00
# 2          2010           117.00  Action,Adventure,Thriller 32.00
# 3          2011           127.00        Action,Drama,Family 31.00
# 4          2019           122.00    Action,Adventure,Sci-Fi 24.00
# ..          ...              ...                        ...   ...
# 193        2017           106.00       Action,Drama,History 69.00
# 194        2018           118.00    Action,Adventure,Comedy 41.00
# 195        2018           119.00    Action,Adventure,Comedy 15.00
# 196        2018           102.00  Action,Adventure,Thriller 78.00
# 197        2019           113.00    Action,Adventure,Sci-Fi  3.00
#
#      release_date  production_budget  domestic_gross  worldwide_gross  \
# 0    Jun 12, 2015       215000000.00    652270625.00    1648854864.00
# 1     Mar 9, 2012       275000000.00     73058679.00     282778100.00
# 2    Jun 11, 2010       110000000.00     77222099.00     177241171.00
# 3     Oct 7, 2011       110000000.00     85463309.00     263880341.00
# 4    Feb 14, 2019       170000000.00     85710210.00     402976036.00
# ..            ...                ...             ...              ...
# 193  Jul 21, 2017       150000000.00    190068280.00     499837368.00
# 194   Jul 6, 2018       130000000.00    216648740.00     623144660.00
# 195  May 18, 2018       110000000.00    324591735.00     786680557.00
# 196  Jul 13, 2018       125000000.00     68420120.00     304115534.00
# 197   Jun 7, 2019       350000000.00     42762350.00     149762350.00
#
#      net_pre_marketing  domestic/world  earnings/cost_ratio  year_released  \
# 0        1433854864.00            0.40                 6.67        2015.00
# 1           7778100.00            0.26                 0.03        2012.00
# 2          67241171.00            0.44                 0.61        2010.00
# 3         153880341.00            0.32                 1.40        2011.00
# 4         232976036.00            0.21                 1.37        2019.00
# ..                 ...             ...                  ...            ...
# 193       349837368.00            0.38                 2.33        2017.00
# 194       493144660.00            0.35                 3.79        2018.00
# 195       676680557.00            0.41                 6.15        2018.00
# 196       179115534.00            0.22                 1.43        2018.00
# 197      -200237650.00            0.29                -0.57        2019.00
#
#      Profitable?
# 0           True
# 1          False
# 2          False
# 3           True
# 4           True
# ..           ...
# 193         True
# 194         True
# 195         True
# 196         True
# 197        False
#
# [198 rows x 18 columns]

# %%
horrortableau=pd.read_csv('horror_table.csv')
horrortableau
# Out:
#      Unnamed: 0     tconst  averagerating  numvotes               movie  \
# 0            70  tt0431021            5.9   53649.0      The Possession
# 1           102  tt0455407            6.5  104465.0         The Crazies
# 2           122  tt0464154            5.4   81327.0          Piranha 3D
# 3           177  tt0498381            4.5   34151.0               Rings
# 4           203  tt0780653            5.8   97873.0         The Wolfman
# ..          ...        ...            ...       ...                 ...
# 157       57280  tt6857112            7.1  102511.0                  Us
# 158       57914  tt6998518            6.6   44378.0               Mandy
# 159       58547  tt7153766            6.4   32049.0              Unsane
# 160       61203  tt7784604            7.3  151571.0          Hereditary
# 161       62412  tt8155288            6.3   27462.0  Happy Death Day 2U
#
#      start_year  runtime_minutes                   genres    id  release_date  \
# 0          2012             92.0  Horror,Mystery,Thriller  81.0  Aug 31, 2012
# 1          2010            101.0          Horror,Thriller  36.0  Feb 26, 2010
# 2          2010             88.0            Comedy,Horror  52.0  Aug 20, 2010
# 3          2017            102.0     Drama,Horror,Mystery  38.0   Feb 3, 2017
# 4          2010            103.0     Drama,Fantasy,Horror  91.0  Feb 12, 2010
# ..          ...              ...                      ...   ...           ...
# 157        2019            116.0  Horror,Mystery,Thriller  88.0  Mar 22, 2019
# 158        2018            121.0    Action,Fantasy,Horror  71.0  Sep 14, 2018
# 159        2018             98.0     Drama,Horror,Mystery  70.0  Mar 23, 2018
# 160        2018            127.0     Drama,Horror,Mystery  56.0   Jun 8, 2018
# 161        2019            100.0     Drama,Horror,Mystery  78.0  Feb 13, 2019
#
#      production_budget  domestic_gross  worldwide_gross  net_pre_marketing  \
# 0           14000000.0      49130588.0       82925064.0         68925064.0
# 1           19000000.0      39123589.0       56445534.0         37445534.0
# 2           24000000.0      25003155.0       83660160.0         59660160.0
# 3           25000000.0      27793018.0       82917283.0         57917283.0
# 4          150000000.0      62189884.0      142634358.0         -7365642.0
# ..                 ...             ...              ...                ...
# 157         20000000.0     175006930.0      254210310.0        234210310.0
# 158          6000000.0       1214525.0        1427656.0         -4572344.0
# 159          1500000.0       7690044.0       14244931.0         12744931.0
# 160         10000000.0      44069456.0       70133905.0         60133905.0
# 161          9000000.0      28051045.0       64179495.0         55179495.0
#
#      domestic/world  earnings/cost_ratio  year_released  Profitable?
# 0          0.592470             4.923219         2012.0         True
# 1          0.693121             1.970818         2010.0         True
# 2          0.298866             2.485840         2010.0         True
# 3          0.335190             2.316691         2017.0         True
# 4          0.436009            -0.049104         2010.0        False
# ..              ...                  ...            ...          ...
# 157        0.688434            11.710515         2019.0         True
# 158        0.850713            -0.762057         2018.0        False
# 159        0.539844             8.496621         2018.0         True
# 160        0.628362             6.013390         2018.0         True
# 161        0.437072             6.131055         2019.0         True
#
# [162 rows x 18 columns]

# %%
len(horrortableau)
# Out:
# 162

# %%
horrorover3mil=horrortableau.loc[horrortableau['production_budget']>=3000000]
horrorover3mil
# Out:
#      Unnamed: 0     tconst  averagerating  numvotes               movie  \
# 0            70  tt0431021            5.9   53649.0      The Possession
# 1           102  tt0455407            6.5  104465.0         The Crazies
# 2           122  tt0464154            5.4   81327.0          Piranha 3D
# 3           177  tt0498381            4.5   34151.0               Rings
# 4           203  tt0780653            5.8   97873.0         The Wolfman
# ..          ...        ...            ...       ...                 ...
# 156       56894  tt6772950            5.2   33621.0       Truth or Dare
# 157       57280  tt6857112            7.1  102511.0                  Us
# 158       57914  tt6998518            6.6   44378.0               Mandy
# 160       61203  tt7784604            7.3  151571.0          Hereditary
# 161       62412  tt8155288            6.3   27462.0  Happy Death Day 2U
#
#      start_year  runtime_minutes                   genres    id  release_date  \
# 0          2012             92.0  Horror,Mystery,Thriller  81.0  Aug 31, 2012
# 1          2010            101.0          Horror,Thriller  36.0  Feb 26, 2010
# 2          2010             88.0            Comedy,Horror  52.0  Aug 20, 2010
# 3          2017            102.0     Drama,Horror,Mystery  38.0   Feb 3, 2017
# 4          2010            103.0     Drama,Fantasy,Horror  91.0  Feb 12, 2010
# ..          ...              ...                      ...   ...           ...
# 156        2018            100.0          Horror,Thriller  91.0  Apr 13, 2018
# 157        2019            116.0  Horror,Mystery,Thriller  88.0  Mar 22, 2019
# 158        2018            121.0    Action,Fantasy,Horror  71.0  Sep 14, 2018
# 160        2018            127.0     Drama,Horror,Mystery  56.0   Jun 8, 2018
# 161        2019            100.0     Drama,Horror,Mystery  78.0  Feb 13, 2019
#
#      production_budget  domestic_gross  worldwide_gross  net_pre_marketing  \
# 0           14000000.0      49130588.0       82925064.0         68925064.0
# 1           19000000.0      39123589.0       56445534.0         37445534.0
# 2           24000000.0      25003155.0       83660160.0         59660160.0
# 3           25000000.0      27793018.0       82917283.0         57917283.0
# 4          150000000.0      62189884.0      142634358.0         -7365642.0
# ..                 ...             ...              ...                ...
# 156          3500000.0      41411015.0       95127344.0         91627344.0
# 157         20000000.0     175006930.0      254210310.0        234210310.0
# 158          6000000.0       1214525.0        1427656.0         -4572344.0
# 160         10000000.0      44069456.0       70133905.0         60133905.0
# 161          9000000.0      28051045.0       64179495.0         55179495.0
#
#      domestic/world  earnings/cost_ratio  year_released  Profitable?
# 0          0.592470             4.923219         2012.0         True
# 1          0.693121             1.970818         2010.0         True
# 2          0.298866             2.485840         2010.0         True
# 3          0.335190             2.316691         2017.0         True
# 4          0.436009            -0.049104         2010.0        False
# ..              ...                  ...            ...          ...
# 156        0.435322            26.179241         2018.0         True
# 157        0.688434            11.710515         2019.0         True
# 158        0.850713            -0.762057         2018.0        False
# 160        0.628362             6.013390         2018.0         True
# 161        0.437072             6.131055         2019.0         True
#
# [136 rows x 18 columns]

# %%
horrortableau=horrortableau.round(decimals=3)
horrortableau.describe()
# Out:
#          Unnamed: 0  averagerating       numvotes   start_year  \
# count    162.000000     162.000000     162.000000   162.000000
# mean   18132.592593       5.869753   85252.592593  2013.913580
# std    17741.029932       0.826734   85637.136751     2.664221
# min       70.000000       3.200000   10217.000000  2010.000000
# 25%     2828.250000       5.300000   33381.750000  2011.250000
# 50%    11348.500000       5.900000   57796.000000  2014.000000
# 75%    31712.500000       6.400000  106295.750000  2016.000000
# max    62412.000000       7.700000  553751.000000  2019.000000
#
#        runtime_minutes          id  production_budget  domestic_gross  \
# count       162.000000  162.000000       1.620000e+02    1.620000e+02
# mean         98.888889   51.987654       1.861679e+07    3.538752e+07
# std          11.731467   27.359577       2.913995e+07    4.522432e+07
# min          80.000000    1.000000       7.000000e+04    0.000000e+00
# 25%          91.000000   31.250000       4.000000e+06    3.717054e+06
# 50%          97.000000   54.500000       9.450000e+06    2.471731e+07
# 75%         105.000000   73.750000       2.000000e+07    4.792146e+07
# max         152.000000  100.000000       1.900000e+08    3.274817e+08
#
#        worldwide_gross  net_pre_marketing  domestic/world  \
# count     1.620000e+02       1.620000e+02      162.000000
# mean      7.915834e+07       6.054155e+07        0.462593
# std       1.047960e+08       9.196127e+07        0.247853
# min       7.556000e+03      -1.296538e+07        0.000000
# 25%       1.143136e+07       1.591438e+05        0.329000
# 50%       4.358745e+07       2.906583e+07        0.488000
# 75%       9.957262e+07       8.502316e+07        0.628750
# max       6.974580e+08       6.624580e+08        1.000000
#
#        earnings/cost_ratio  year_released
# count           162.000000     162.000000
# mean             10.484191    2014.074074
# std              35.247170       2.605669
# min              -0.998000    2010.000000
# 25%               0.039500    2012.000000
# 50%               2.307500    2014.000000
# 75%               8.406750    2016.000000
# max             415.565000    2019.000000

# %%
totalhorroroverbudget=len(horrorover3mil['movie'])
totalhorroroverbudget
# Out:
# 136

# %%
pd.options.display.float_format='{:.2f}'.format

# %%
horrortableau.describe()
# Out:
#        Unnamed: 0  averagerating  numvotes  start_year  runtime_minutes  \
# count      162.00         162.00    162.00      162.00           162.00
# mean     18132.59           5.87  85252.59     2013.91            98.89
# std      17741.03           0.83  85637.14        2.66            11.73
# min         70.00           3.20  10217.00     2010.00            80.00
# 25%       2828.25           5.30  33381.75     2011.25            91.00
# 50%      11348.50           5.90  57796.00     2014.00            97.00
# 75%      31712.50           6.40 106295.75     2016.00           105.00
# max      62412.00           7.70 553751.00     2019.00           152.00
#
#           id  production_budget  domestic_gross  worldwide_gross  \
# count 162.00             162.00          162.00           162.00
# mean   51.99        18616790.12     35387515.15      79158339.41
# std    27.36        29139949.60     45224321.85     104795979.93
# min     1.00           70000.00            0.00          7556.00
# 25%    31.25         4000000.00      3717054.00      11431361.75
# 50%    54.50         9450000.00     24717313.50      43587448.50
# 75%    73.75        20000000.00     47921458.50      99572618.50
# max   100.00       190000000.00    327481748.00     697457969.00
#
#        net_pre_marketing  domestic/world  earnings/cost_ratio  year_released
# count             162.00          162.00               162.00         162.00
# mean         60541549.28            0.46                10.48        2014.07
# std          91961269.03            0.25                35.25           2.61
# min         -12965385.00            0.00                -1.00        2010.00
# 25%            159143.75            0.33                 0.04        2012.00
# 50%          29065832.00            0.49                 2.31        2014.00
# 75%          85023157.75            0.63                 8.41        2016.00
# max         662457969.00            1.00               415.56        2019.00

# %%
totalhorroroverbudgetsuccess=len(horrorover3mil.loc[horrorover3mil['earnings/cost_ratio']>=1])

# %%
totalhorroroverbudgetsuccess/totalhorroroverbudget
# Out:
# 0.6323529411764706

# %%
horrorover3mil['movie' and'earnings/cost_ratio']
# Out:
# 0      4.92
# 1      1.97
# 2      2.49
# 3      2.32
# 4     -0.05
#        ...
# 156   26.18
# 157   11.71
# 158   -0.76
# 160    6.01
# 161    6.13
# Name: earnings/cost_ratio, Length: 136, dtype: float64

# %%
sn.scatterplot(data=actiontableau, x="production_budget", y="earnings/cost_ratio")
# Out:
# <AxesSubplot:xlabel='production_budget', ylabel='earnings/cost_ratio'>

# %%
import matplotlib.pyplot as plt
sn.set_theme()

# Load the example flights dataset and convert to long-form
horror = sns.load_dataset("horrortableau")
flights = flights_long.pivot("month", "year", "passengers")

# Draw a heatmap with the numeric values in each cell
f, ax = plt.subplots(figsize=(9, 6))
sns.heatmap(flights, annot=True, fmt="d", linewidths=.5, ax=ax)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-52-3244ad819599> in <module>
#       3
#       4 # Load the example flights dataset and convert to long-form
# ----> 5 horror = sns.load_dataset("horrortableau")
#       6 flights = flights_long.pivot("month", "year", "passengers")
#       7
#
# NameError: name 'sns' is not defined

# %%
sn.catplot(data=horrortableau, kind="swarm", x="year_released", y="net_pre_marketing")
# Out:
# /opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/seaborn/categorical.py:1296: UserWarning: 25.0% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# /opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/seaborn/categorical.py:1296: UserWarning: 14.3% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# /opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/seaborn/categorical.py:1296: UserWarning: 10.5% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# /opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/seaborn/categorical.py:1296: UserWarning: 21.1% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)

# %%
import matplotlib.colors as mcolors

# %%
actiontableau
# Out:
#      Unnamed: 0     tconst  averagerating  numvotes                 movie  \
# 0            39  tt0369610           7.00 539338.00        Jurassic World
# 1            50  tt0401729           6.60 241792.00           John Carter
# 2            68  tt0429493           6.80 235256.00            The A-Team
# 3            72  tt0433035           7.10 283534.00            Real Steel
# 4            78  tt0437086           7.50  88207.00   Alita: Battle Angel
# ..          ...        ...            ...       ...                   ...
# 193       45547  tt5013056           7.90 466580.00               Dunkirk
# 194       46167  tt5095030           7.10 244024.00  Ant-Man and the Wasp
# 195       48760  tt5463162           7.80 391735.00            Deadpool 2
# 196       50822  tt5758778           5.80  81193.00            Skyscraper
# 197       56025  tt6565702           6.00  24451.00          Dark Phoenix
#
#      start_year  runtime_minutes                     genres    id  \
# 0          2015           124.00    Action,Adventure,Sci-Fi 34.00
# 1          2012           132.00    Action,Adventure,Sci-Fi 14.00
# 2          2010           117.00  Action,Adventure,Thriller 32.00
# 3          2011           127.00        Action,Drama,Family 31.00
# 4          2019           122.00    Action,Adventure,Sci-Fi 24.00
# ..          ...              ...                        ...   ...
# 193        2017           106.00       Action,Drama,History 69.00
# 194        2018           118.00    Action,Adventure,Comedy 41.00
# 195        2018           119.00    Action,Adventure,Comedy 15.00
# 196        2018           102.00  Action,Adventure,Thriller 78.00
# 197        2019           113.00    Action,Adventure,Sci-Fi  3.00
#
#      release_date  production_budget  domestic_gross  worldwide_gross  \
# 0    Jun 12, 2015       215000000.00    652270625.00    1648854864.00
# 1     Mar 9, 2012       275000000.00     73058679.00     282778100.00
# 2    Jun 11, 2010       110000000.00     77222099.00     177241171.00
# 3     Oct 7, 2011       110000000.00     85463309.00     263880341.00
# 4    Feb 14, 2019       170000000.00     85710210.00     402976036.00
# ..            ...                ...             ...              ...
# 193  Jul 21, 2017       150000000.00    190068280.00     499837368.00
# 194   Jul 6, 2018       130000000.00    216648740.00     623144660.00
# 195  May 18, 2018       110000000.00    324591735.00     786680557.00
# 196  Jul 13, 2018       125000000.00     68420120.00     304115534.00
# 197   Jun 7, 2019       350000000.00     42762350.00     149762350.00
#
#      net_pre_marketing  domestic/world  earnings/cost_ratio  year_released  \
# 0        1433854864.00            0.40                 6.67        2015.00
# 1           7778100.00            0.26                 0.03        2012.00
# 2          67241171.00            0.44                 0.61        2010.00
# 3         153880341.00            0.32                 1.40        2011.00
# 4         232976036.00            0.21                 1.37        2019.00
# ..                 ...             ...                  ...            ...
# 193       349837368.00            0.38                 2.33        2017.00
# 194       493144660.00            0.35                 3.79        2018.00
# 195       676680557.00            0.41                 6.15        2018.00
# 196       179115534.00            0.22                 1.43        2018.00
# 197      -200237650.00            0.29                -0.57        2019.00
#
#      Profitable?
# 0           True
# 1          False
# 2          False
# 3           True
# 4           True
# ..           ...
# 193         True
# 194         True
# 195         True
# 196         True
# 197        False
#
# [198 rows x 18 columns]

# %%
len(actiontableau.loc[actiontableau['ec_ratio']>=1])/len(actiontableau)
# Out:
# 0.6717171717171717

# %%
avgnet_profit_action=dict(actiontableau.groupby('genres').net_pre_marketing.mean())
sorted_data = sorted(avgnet_profit_action.items(), key=lambda x: x[1], reverse=True)
avgnet_profit_action_sorted =dict(sorted_data[0:10])
avgnet_profit_action_sorted
plot_two_, plot_two_ax_= plt.subplots(figsize=(20, 10))
plot_two_ax_.bar(avgnet_profit_action_sorted.keys(),avgnet_profit_action_sorted.values(), color = 'olive')
plot_two_ax_.set_title('Average Net Profit For Movies with Action Tag', fontsize=25)
plot_two_ax_.set_ylabel('Net Profit', fontsize=20)
plot_two_ax_.set_xlabel('Genre Name', fontsize=20)

plt.xticks(rotation=90, size=18)
plt.yticks(size = 20);

# %%
avgnet_profit_action_sorted
# Out:
# {'Action,Adventure,Sci-Fi': 511433347.79591835,
#  'Action,Crime,Thriller': 479543282.8333333,
#  'Action,Sci-Fi,Thriller': 429212307.0,
#  'Action,Adventure,Animation': 382554265.0769231,
#  'Action,Adventure,Comedy': 353457716.4705882,
#  'Action,Horror,Sci-Fi': 351530715.0,
#  'Action,Adventure,Horror': 341514650.0,
#  'Action,Thriller': 298291292.4,
#  'Action,Adventure,Fantasy': 273067383.1034483,
#  'Action,Adventure,Thriller': 244711709.33333334}

# %%
avgnet_profit_horror=dict(horrortableau.groupby('genres').net_pre_marketing.mean())
sorted_data2 = sorted(avgnet_profit_horror.items(), key=lambda x: x[1], reverse=True)
avgnet_profit_horror_sorted =dict(sorted_data2[0:10])
avgnet_profit_horror_sorted
plot_three_, plot_three_ax_= plt.subplots(figsize=(20, 10))
plot_three_ax_.bar(avgnet_profit_horror_sorted.keys(),avgnet_profit_horror_sorted.values(), color = 'olive')
plot_three_ax_.set_title('Average Net Profit For Movies with Horror Tag', fontsize=25)
plot_three_ax_.set_ylabel('Net Profit', fontsize=20)
plot_three_ax_.set_xlabel('Genre Name', fontsize=20)


plt.xticks(rotation=90, size=18);
plt.yticks(size = 20)
plt.xticks();

# %%
sorted_data2[0:10]
# Out:
# [('Action,Adventure,Horror', 202640185.0),
#  ('Action,Horror,Sci-Fi', 162177890.42857143),
#  ('Horror,Mystery,Thriller', 104884438.23333333),
#  ('Comedy,Horror,Romance', 85121608.0),
#  ('Horror,Thriller', 67481521.48),
#  ('Horror', 66284242.85714286),
#  ('Action,Fantasy,Horror', 49592588.833333336),
#  ('Drama,Horror,Sci-Fi', 48754278.0),
#  ('Fantasy,Horror,Thriller', 47452391.5),
#  ('Drama,Horror,Thriller', 46600809.4)]

# %%
horrortableau = horrortableau.rename(columns = {'earnings/cost_ratio': 'ec_ratio'})
actiontableau = actiontableau.rename(columns = {'earnings/cost_ratio': 'ec_ratio'})

# %%
avgnet_ec_horror=dict(horrortableau.groupby('genres').ec_ratio.mean())
sorted_data3 = sorted(avgnet_ec_horror.items(), key=lambda x: x[1], reverse=True)
avgnet_ec_horror_sorted =dict(sorted_data3[0:10])
avgnet_ec_horror_sorted
plot_three1_, plot_three1_ax_= plt.subplots(figsize=(20, 10))
plot_three1_ax_.bar(avgnet_ec_horror_sorted.keys(),avgnet_ec_horror_sorted.values(), color = 'darkkhaki')
plot_three1_ax_.set_title('Average Earnings per Cost Ratio by Genre - Horror Movies', fontsize=25)
plot_three1_ax_.set_ylabel('Average Earnings Per Cost Ratio', fontsize=20)
plot_three1_ax_.set_xlabel('Genre Name', fontsize=20)

plt.xticks(rotation=90, size=18)
plt.yticks(size =20);

# %%
avgnet_ec_horror_sorted
# Out:
# {'Horror,Mystery,Thriller': 32.186933333333336,
#  'Horror': 24.25857142857143,
#  'Adventure,Horror': 11.931,
#  'Drama,Horror,Thriller': 11.383600000000001,
#  'Crime,Horror,Mystery': 8.157,
#  'Horror,Thriller': 7.3952,
#  'Adventure,Horror,Mystery': 7.365,
#  'Horror,Mystery': 6.67,
#  'Drama,Horror,Mystery': 6.383785714285715,
#  'Action,Horror,Sci-Fi': 6.170714285714285}

# %%
avgnet_ec_action=dict(actiontableau.groupby('genres').ec_ratio.mean())
sorted_data4 = sorted(avgnet_ec_action.items(), key=lambda x: x[1], reverse=True)
avgnet_ec_action_sorted =dict(sorted_data4[0:10])
avgnet_ec_action_sorted
plot_three2_, plot_three2_ax_= plt.subplots(figsize=(20, 10))
plot_three2_ax_.bar(avgnet_ec_action_sorted.keys(),avgnet_ec_action_sorted.values(), color = 'darkkhaki')
plot_three2_ax_.set_title('Average Earnings per Cost Ratio by Genre- Action Movies', fontsize=25)
plot_three2_ax_.set_ylabel('Average Earnings Per Cost Ratio', fontsize=20)
plot_three2_ax_.set_xlabel('Genre Name', fontsize=20)

plt.xticks(rotation=90, size=18)
plt.yticks(size = 20);

# %%
avgnet_ec_action_sorted
# Out:
# {'Action,Sci-Fi,Thriller': 3.7834136872413793,
#  'Action,Adventure,Comedy': 3.007368328934492,
#  'Action,Adventure,Sci-Fi': 2.8474135630197566,
#  'Action,Animation,Comedy': 2.7285716940375835,
#  'Action,Crime,Thriller': 2.610455238881294,
#  'Action,Adventure,Animation': 2.5550275835469427,
#  'Action,Adventure,Crime': 2.221889879111111,
#  'Action,Fantasy,War': 2.007091372727273,
#  'Action,Thriller': 1.9865340848503075,
#  'Action,Drama,Fantasy': 1.9835713976190474}

# %%
firstq_horrortableau=horrortableau.loc[horrortableau['production_budget']<=4000000]
len(firstq_horrortableau)
# Out:
# 43

# %%
len(firstq_horrortableau.loc[firstq_horrortableau['ec_ratio']>=1])
# Out:
# 23

# %%
len(firstq_horrortableau.loc[firstq_horrortableau['ec_ratio']>=1])/len(firstq_horrortableau)
# Out:
# 0.5348837209302325

# %%
secondq_horrortableau=horrortableau.loc[(horrortableau['production_budget']>4000000) & (horrortableau['production_budget']<=9450000.00)]
secondq_horrortableau
# Out:
#      Unnamed: 0     tconst  averagerating  numvotes  \
# 15          859  tt1082807           6.10  38378.00
# 19         1057  tt1179933           7.20 260383.00
# 20         1144  tt1204977           4.50  44054.00
# 27         1561  tt1285009           5.20  21614.00
# 44         3453  tt1519461           4.20  11537.00
# 46         3541  tt1525366           6.30  15727.00
# 54         4440  tt1582507           5.60  66303.00
# 65         6527  tt1675192           7.40  83200.00
# 66         6809  tt1687901           6.50  60215.00
# 75         8960  tt1772240           5.20  51427.00
# 76         9189  tt1778304           5.80  85689.00
# 82        11651  tt1881002           5.60  38671.00
# 86        13195  tt1974419           6.20  72359.00
# 94        15959  tt2109184           4.60  58408.00
# 101       21689  tt2388715           6.50 106906.00
# 105       23089  tt2473682           5.00  37147.00
# 109       25910  tt2752758           4.10  15502.00
# 112       26898  tt2870612           6.20  66892.00
# 113       27290  tt2918436           5.20  37675.00
# 114       27887  tt2975578           6.50 126203.00
# 117       30337  tt3216348           5.30  10217.00
# 120       31486  tt3322940           5.40 122039.00
# 125       33977  tt3567288           6.20 102459.00
# 126       35277  tt3702652           5.30  15813.00
# 130       36871  tt3860916           6.30  27339.00
# 132       38180  tt4030600           4.30  17743.00
# 134       38452  tt4062536           7.00  90773.00
# 138       40897  tt4361050           6.10  47099.00
# 139       41891  tt4504044           5.90  11456.00
# 140       42036  tt4520364           5.80  35487.00
# 141       43368  tt4695012           6.20  69039.00
# 144       43914  tt4786282           6.30 100650.00
# 145       45295  tt4972582           7.30 358543.00
# 146       45817  tt5052448           7.70 400474.00
# 148       47897  tt5308322           6.50  87132.00
# 153       50672  tt5734576           5.20  11629.00
# 158       57914  tt6998518           6.60  44378.00
# 161       62412  tt8155288           6.30  27462.00
#
#                                     movie  start_year  runtime_minutes  \
# 15                   The Belko Experiment        2016            89.00
# 19                    10 Cloverfield Lane        2016           103.00
# 20                                  Ouija        2014            89.00
# 27           The Strangers: Prey at Night        2018            85.00
# 44                                Area 51        2015            91.00
# 46                               Grabbers        2012            94.00
# 54         House at the End of the Street        2012           101.00
# 65                           Take Shelter        2011           121.00
# 66                          The Awakening        2011           102.00
# 75                              Apollo 18        2011            86.00
# 76                  Paranormal Activity 3        2011            83.00
# 82                                 Maggie        2015            95.00
# 86                         The Neon Demon        2016           117.00
# 94                  Paranormal Activity 4        2012            88.00
# 101                                Oculus        2013           104.00
# 105  Paranormal Activity: The Marked Ones        2014            84.00
# 109                           Devil's Due        2014            89.00
# 112                    As Above, So Below        2014            93.00
# 113                    The Lazarus Effect        2015            83.00
# 114                    The Purge: Anarchy        2014           103.00
# 117                             Incarnate        2016            91.00
# 120                             Annabelle        2014            99.00
# 125                             The Visit        2015            94.00
# 126            The Other Side of the Door        2016            96.00
# 130                                 Cargo        2017           105.00
# 132                       The Bye Bye Man        2017            96.00
# 134                            Green Room        2015            95.00
# 138                 Ouija: Origin of Evil        2016            99.00
# 139                           The Prodigy        2019            92.00
# 140                                Morgan        2016            92.00
# 141                     It Comes at Night        2017            91.00
# 144                            Lights Out        2016            81.00
# 145                                 Split        2016           117.00
# 146                               Get Out        2017           104.00
# 148                       Happy Death Day        2017            96.00
# 153        The Possession of Hannah Grace        2018            86.00
# 158                                 Mandy        2018           121.00
# 161                    Happy Death Day 2U        2019           100.00
#
#                        genres    id  release_date  production_budget  \
# 15            Horror,Thriller 21.00  Mar 17, 2017         5000000.00
# 19       Drama,Horror,Mystery 54.00  Mar 11, 2016         5000000.00
# 20    Horror,Mystery,Thriller 60.00  Oct 24, 2014         5000000.00
# 27                     Horror 79.00   Mar 9, 2018         5000000.00
# 44     Horror,Sci-Fi,Thriller 81.00  May 15, 2015         5000000.00
# 46       Comedy,Horror,Sci-Fi 38.00  Jul 19, 2013         5300000.00
# 54      Drama,Horror,Thriller 73.00  Sep 21, 2012         6900000.00
# 65      Drama,Horror,Thriller  9.00  Sep 30, 2011         4750000.00
# 66            Horror,Thriller  4.00  Aug 17, 2012         4900000.00
# 75      Horror,Mystery,Sci-Fi 94.00   Sep 2, 2011         5000000.00
# 76    Horror,Mystery,Thriller 51.00  Oct 21, 2011         5000000.00
# 82               Drama,Horror 47.00   May 8, 2015         4500000.00
# 86            Horror,Thriller 68.00  Jun 24, 2016         7500000.00
# 94    Horror,Mystery,Thriller 59.00  Oct 19, 2012         5000000.00
# 101            Horror,Mystery 72.00  Apr 11, 2014         5000000.00
# 105   Horror,Mystery,Thriller 70.00   Jan 3, 2014         5000000.00
# 109   Horror,Mystery,Thriller 14.00  Jan 17, 2014         7000000.00
# 112  Adventure,Horror,Mystery 84.00  Aug 29, 2014         5000000.00
# 113     Horror,Mystery,Sci-Fi 76.00  Feb 27, 2015         5000000.00
# 114      Action,Horror,Sci-Fi 71.00  Jul 18, 2014         9000000.00
# 117           Horror,Thriller 39.00   Dec 2, 2016         5000000.00
# 120   Horror,Mystery,Thriller 84.00   Oct 3, 2014         6500000.00
# 125   Horror,Mystery,Thriller 56.00  Sep 11, 2015         5000000.00
# 126                    Horror 49.00   Mar 4, 2016         5000000.00
# 130       Drama,Horror,Sci-Fi 73.00  Oct 21, 2011         4200000.00
# 132      Drama,Fantasy,Horror 77.00  Jan 13, 2017         7400000.00
# 134     Horror,Music,Thriller 46.00  Apr 15, 2016         5000000.00
# 138      Drama,Horror,Mystery 75.00  Oct 21, 2016         9000000.00
# 139           Horror,Thriller 36.00   Feb 8, 2019         6000000.00
# 140      Action,Horror,Sci-Fi  5.00   Sep 2, 2016         8000000.00
# 141            Horror,Mystery  4.00   Jun 9, 2017         5000000.00
# 144      Drama,Horror,Mystery 55.00  Jul 22, 2016         5000000.00
# 145           Horror,Thriller 50.00  Jan 20, 2017         5000000.00
# 146   Horror,Mystery,Thriller 49.00  Feb 24, 2017         5000000.00
# 148   Horror,Mystery,Thriller 58.00  Oct 13, 2017         5000000.00
# 153   Horror,Mystery,Thriller 37.00  Nov 30, 2018         6000000.00
# 158     Action,Fantasy,Horror 71.00  Sep 14, 2018         6000000.00
# 161      Drama,Horror,Mystery 78.00  Feb 13, 2019         9000000.00
#
#      domestic_gross  worldwide_gross  net_pre_marketing  domestic/world  \
# 15      10166820.00      11792942.00         6792942.00            0.86
# 19      72082999.00     108286422.00       103286422.00            0.67
# 20      50856010.00     103300632.00        98300632.00            0.49
# 27      24431472.00      29960051.00        24960051.00            0.81
# 44          7556.00          7556.00        -4992444.00            1.00
# 46             0.00        440821.00        -4859179.00            0.00
# 54      31611916.00      44103982.00        37203982.00            0.72
# 65       1728953.00       4972016.00          222016.00            0.35
# 66         95933.00       6924321.00         2024321.00            0.01
# 75      17686929.00      26517819.00        21517819.00            0.67
# 76     104028807.00     207039844.00       202039844.00            0.50
# 82        187112.00       1027760.00        -3472240.00            0.18
# 86       1333124.00       3559803.00        -3940197.00            0.37
# 94      53900335.00     142817992.00       137817992.00            0.38
# 101     27695246.00      44115496.00        39115496.00            0.63
# 105     32462372.00      90904854.00        85904854.00            0.36
# 109     15821461.00      36146087.00        29146087.00            0.44
# 112     21222315.00      41824066.00        36824066.00            0.51
# 113     25801570.00      38359310.00        33359310.00            0.67
# 114     71562550.00     111534881.00       102534881.00            0.64
# 117      4799774.00       9371036.00         4371036.00            0.51
# 120     84273813.00     256862920.00       250362920.00            0.33
# 125     65206105.00      98677816.00        93677816.00            0.66
# 126      3000342.00      12905107.00         7905107.00            0.23
# 130            0.00        313230.00        -3886770.00            0.00
# 132     22395806.00      31187727.00        23787727.00            0.72
# 134      3220371.00       3807503.00        -1192497.00            0.85
# 138     35144505.00      81831866.00        72831866.00            0.43
# 139     14856291.00      19789712.00        13789712.00            0.75
# 140      3915251.00       7298786.00         -701214.00            0.54
# 141     13985117.00      19720203.00        14720203.00            0.71
# 144     67268835.00     148806510.00       143806510.00            0.45
# 145    138141585.00     278964806.00       273964806.00            0.49
# 146    176040665.00     255367951.00       250367951.00            0.69
# 148     55683845.00     125010260.00       120010260.00            0.45
# 153     14836174.00      42785387.00        36785387.00            0.35
# 158      1214525.00       1427656.00        -4572344.00            0.85
# 161     28051045.00      64179495.00        55179495.00            0.44
#
#      ec_ratio  year_released  Profitable?
# 15       1.36        2017.00         True
# 19      20.66        2016.00         True
# 20      19.66        2014.00         True
# 27       4.99        2018.00         True
# 44      -1.00        2015.00        False
# 46      -0.92        2013.00        False
# 54       5.39        2012.00         True
# 65       0.05        2011.00        False
# 66       0.41        2012.00        False
# 75       4.30        2011.00         True
# 76      40.41        2011.00         True
# 82      -0.77        2015.00        False
# 86      -0.53        2016.00        False
# 94      27.56        2012.00         True
# 101      7.82        2014.00         True
# 105     17.18        2014.00         True
# 109      4.16        2014.00         True
# 112      7.37        2014.00         True
# 113      6.67        2015.00         True
# 114     11.39        2014.00         True
# 117      0.87        2016.00        False
# 120     38.52        2014.00         True
# 125     18.74        2015.00         True
# 126      1.58        2016.00         True
# 130     -0.93        2011.00        False
# 132      3.21        2017.00         True
# 134     -0.24        2016.00        False
# 138      8.09        2016.00         True
# 139      2.30        2019.00         True
# 140     -0.09        2016.00        False
# 141      2.94        2017.00         True
# 144     28.76        2016.00         True
# 145     54.79        2017.00         True
# 146     50.07        2017.00         True
# 148     24.00        2017.00         True
# 153      6.13        2018.00         True
# 158     -0.76        2018.00        False
# 161      6.13        2019.00         True

# %%
len(secondq_horrortableau.loc[secondq_horrortableau['ec_ratio']>=1])/len(secondq_horrortableau)
# Out:
# 0.7105263157894737

# %%
thirdq_horrortableau=horrortableau.loc[(horrortableau['production_budget']<=20000000.00) & (horrortableau['production_budget']>9450000.00)]
len(thirdq_horrortableau)
# Out:
# 41

# %%
len(thirdq_horrortableau.loc[thirdq_horrortableau['ec_ratio']>=1])/len(thirdq_horrortableau)
# Out:
# 0.6585365853658537

# %%
fourthq_horrortableau=horrortableau.loc[horrortableau['production_budget']>20000000.0]
len(fourthq_horrortableau)
# Out:
# 40

# %%
len(fourthq_horrortableau.loc[fourthq_horrortableau['ec_ratio']>=1])/len(fourthq_horrortableau)
# Out:
# 0.575

# %%
labels = 'Profitable Horror Movies in Q1','NonProfitable Horror Movies in Q1'
sizes = [53.5, 46.5]
explode = (0, 0)  
colors = ['darkkhaki', 'beige']
fig1, ax1 = plt.subplots()
ax1.pie(sizes, explode=explode, labels=labels, autopct='%1.1f%%',
        shadow=False, startangle=90, colors=colors)
ax1.axis('equal');

# %%
labels = 'Profitable Horror Movies in Q2','NonProfitable Horror Movies in Q2'
sizes = [71.1, 28.9]
explode = (0, 0) 
colors = ['darkkhaki', 'beige']

fig1, ax1 = plt.subplots()
ax1.pie(sizes, explode=explode, labels=labels, autopct='%1.1f%%',
        shadow=False, startangle=90, colors=colors)
ax1.axis('equal');

# %%
labels = 'Profitable Horror Movies in Q3','NonProfitable Horror Movies in Q3'
sizes = [65.9, 34.1]
explode = (0, 0) 
colors = ['darkkhaki', 'beige']

fig1, ax1 = plt.subplots()
ax1.pie(sizes, explode=explode, labels=labels, autopct='%1.1f%%',
        shadow=False, startangle=90, colors=colors )
ax1.axis('equal');

# %%
labels = 'Profitable Horror Movies in Q4','NonProfitable Horror Movies in Q4'
sizes = [57.5, 42.5]
explode = (0, 0)  
colors = ['darkkhaki', 'beige']

fig1, ax1 = plt.subplots()
ax1.pie(sizes, explode=explode, labels=labels, autopct='%1.1f%%',
        shadow=False, startangle=90, colors=colors)
ax1.axis('equal');
